# %% [markdown]
# # Downloading and Processing Solar Wind Data
# In this notebook we show how we download Solar Wind Data from OMNI, process it and calculate dipole tilt.\
#
# ## Solar Wind Tools
# [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.13749003.svg)](https://doi.org/10.5281/zenodo.13749003)
#
# We rely on the github repository Solar Wind Tools: https://github.com/08walkersj/Solar_Wind_Tools
#
# The batch run function run_all incorporates everything that we need and use in this study.
# - We set start and end year to 2000 and 2003 because this covers more than the period that has all the conjugat onset data points in our study.
# - In the study we use a 2 hour window and apply a 20 minute shift when associating it with the onset dataset
# - the run strings are the same as the default and perform all the available functions to retrieve the solar wind, magnetic index and dipole tilt dataset that is used in this study

# %%
from Solar_Wind_Tools.run_all import run_all
run_all('./omni_data.hdf5',
        key='omni_window_2h_20', window=2*60, shift=20, start_year= 2000, 
        end_year=2003, run=['Download', 'Statistics', 'Coupling', 'Dipole', 'Time Shift'], stats_columns = ['IMF', 'BX_GSE', 'BY_GSM', 'BZ_GSM', 'Vx', 'Vy', 'Vz'])
# Out:
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20001001_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20000601_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20001101_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20000701_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20000101_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20000501_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20000201_v01.cdf
# --2024-12-11 15:46:58--  https://cdaweb.gsfc.nasa.gov/sp_phys/data/omni/hro_1min/2000/omni_hro_1min_20000801_v01.cdf
# ...
